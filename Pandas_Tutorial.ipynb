# %%
import pandas as pd
import json

# %%
df=pd.read_csv('Business-employment-data-september-2022-quarter-csv.csv')

# %%
df
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 0          BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number
# 1          BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number
# 2          BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number
# 3          BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number
# 4          BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number
# ...                ...      ...         ...        ...    ...     ...
# 20636    BDCQ.SEE3999A  2017.06         NaN          Y      C  Number
# 20637    BDCQ.SEE3999A  2017.09         NaN          Y      C  Number
# 20638    BDCQ.SEE3999A  2017.12         NaN          Y      C  Number
# 20639    BDCQ.SEE3999A  2018.03         NaN          Y      C  Number
# 20640    BDCQ.SEE3999A  2018.06         NaN          Y      C  Number
#
#        Magnitude                         Subject  \
# 0              0  Business Data Collection - BDC
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS   UNITS  Magnitude  \
# 0      BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number          0
# 1      BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number          0
# 2      BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number          0
# 3      BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number          0
# 4      BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number          0
#
#                           Subject                            Group  \
# 0  Business Data Collection - BDC  Industry by employment variable
# 1  Business Data Collection - BDC  Industry by employment variable
# 2  Business Data Collection - BDC  Industry by employment variable
# 3  Business Data Collection - BDC  Industry by employment variable
# 4  Business Data Collection - BDC  Industry by employment variable
#
#   Series_title_1                     Series_title_2 Series_title_3  \
# ...

# %%
df.tail()
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 20636    BDCQ.SEE3999A  2017.06         NaN          Y      C  Number
# 20637    BDCQ.SEE3999A  2017.09         NaN          Y      C  Number
# 20638    BDCQ.SEE3999A  2017.12         NaN          Y      C  Number
# 20639    BDCQ.SEE3999A  2018.03         NaN          Y      C  Number
# 20640    BDCQ.SEE3999A  2018.06         NaN          Y      C  Number
#
#        Magnitude                         Subject  \
# 20636          0  Business Data Collection - BDC
# 20637          0  Business Data Collection - BDC
# 20638          0  Business Data Collection - BDC
# 20639          0  Business Data Collection - BDC
# 20640          0  Business Data Collection - BDC
#
#                                               Group  \
# 20636  Territorial authority by employment variable
# 20637  Territorial authority by employment variable
# 20638  Territorial authority by employment variable
# ...

# %%
df1=df.head(2)

# %%
df.tail(2)
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 20639    BDCQ.SEE3999A  2018.03         NaN          Y      C  Number
# 20640    BDCQ.SEE3999A  2018.06         NaN          Y      C  Number
#
#        Magnitude                         Subject  \
# 20639          0  Business Data Collection - BDC
# 20640          0  Business Data Collection - BDC
#
#                                               Group  \
# 20639  Territorial authority by employment variable
# 20640  Territorial authority by employment variable
#
#                                Series_title_1  \
# 20639  Filled jobs (workplace location based)
# 20640  Filled jobs (workplace location based)
#
#                            Series_title_2 Series_title_3  Series_title_4  \
# 20639  Area Outside Territorial Authority         Actual             NaN
# 20640  Area Outside Territorial Authority         Actual             NaN
#
#        Series_title_5
# 20639             NaN
# 20640             NaN

# %%
df1.to_csv("test.csv")

# %%
df2= pd.read_csv("test.csv",sep='@',header=None,skiprows=[0,1])

# %%
df2
# Out:
#    0            1        2        3   4  5       6   7   \
# 0   1  BDCQ.SEA1AA  2011.09  78324.0 NaN  F  Number   0
#
#                                8                                9   \
# 0  Business Data Collection - BDC  Industry by employment variable
#
#             10                                 11      12  13  14
# 0  Filled jobs  Agriculture@ Forestry and Fishing  Actual NaN NaN

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS   UNITS  Magnitude  \
# 0      BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number          0
# 1      BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number          0
# 2      BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number          0
# 3      BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number          0
# 4      BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number          0
#
#                           Subject                            Group  \
# 0  Business Data Collection - BDC  Industry by employment variable
# 1  Business Data Collection - BDC  Industry by employment variable
# 2  Business Data Collection - BDC  Industry by employment variable
# 3  Business Data Collection - BDC  Industry by employment variable
# 4  Business Data Collection - BDC  Industry by employment variable
#
#   Series_title_1                     Series_title_2 Series_title_3  \
# ...

# %%
df=pd.read_csv("Business-employment-data-september-2022-quarter-csv.csv",skiprows=[0,2,4,5])

# %%
df.head(10)
# Out:
#    BDCQ.SEA1AA  2011.06    80078 Unnamed: 3  F  Number  0  \
# 0  BDCQ.SEA1AA  2011.12  85850.0        NaN  F  Number  0
# 1  BDCQ.SEA1AA  2012.09  79261.0        NaN  F  Number  0
# 2  BDCQ.SEA1AA  2012.12  87793.0        NaN  F  Number  0
# 3  BDCQ.SEA1AA  2013.03  91571.0        NaN  F  Number  0
# 4  BDCQ.SEA1AA  2013.06  81687.0        NaN  F  Number  0
# 5  BDCQ.SEA1AA  2013.09  81471.0        NaN  F  Number  0
# 6  BDCQ.SEA1AA  2013.12  93950.0        NaN  F  Number  0
# 7  BDCQ.SEA1AA  2014.03  97208.0        NaN  F  Number  0
# 8  BDCQ.SEA1AA  2014.06  85879.0        NaN  F  Number  0
# 9  BDCQ.SEA1AA  2014.09  84447.0        NaN  F  Number  0
#
#    Business Data Collection - BDC  Industry by employment variable  \
# 0  Business Data Collection - BDC  Industry by employment variable
# 1  Business Data Collection - BDC  Industry by employment variable
# 2  Business Data Collection - BDC  Industry by employment variable
# ...

# %%
df=pd.read_csv("Business-employment-data-september-2022-quarter-csv.csv",skiprows=[0,2,4,5],na_values=['Number'])

# %%
df.head()
# Out:
#    BDCQ.SEA1AA  2011.06    80078 Unnamed: 3  F  Number  0  \
# 0  BDCQ.SEA1AA  2011.12  85850.0        NaN  F  Number  0
# 1  BDCQ.SEA1AA  2012.09  79261.0        NaN  F  Number  0
# 2  BDCQ.SEA1AA  2012.12  87793.0        NaN  F  Number  0
# 3  BDCQ.SEA1AA  2013.03  91571.0        NaN  F  Number  0
# 4  BDCQ.SEA1AA  2013.06  81687.0        NaN  F  Number  0
#
#    Business Data Collection - BDC  Industry by employment variable  \
# 0  Business Data Collection - BDC  Industry by employment variable
# 1  Business Data Collection - BDC  Industry by employment variable
# 2  Business Data Collection - BDC  Industry by employment variable
# 3  Business Data Collection - BDC  Industry by employment variable
# 4  Business Data Collection - BDC  Industry by employment variable
#
#    Filled jobs  Agriculture, Forestry and Fishing  Actual  Unnamed: 12  \
# 0  Filled jobs  Agriculture, Forestry and Fishing  Actual          NaN
# ...

# %%
df=pd.read_csv("Business-employment-data-september-2022-quarter-csv.csv")

# %%
df.head()
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS   UNITS  Magnitude  \
# 0      BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number          0
# 1      BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number          0
# 2      BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number          0
# 3      BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number          0
# 4      BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number          0
#
#                           Subject                            Group  \
# 0  Business Data Collection - BDC  Industry by employment variable
# 1  Business Data Collection - BDC  Industry by employment variable
# 2  Business Data Collection - BDC  Industry by employment variable
# 3  Business Data Collection - BDC  Industry by employment variable
# 4  Business Data Collection - BDC  Industry by employment variable
#
#   Series_title_1                     Series_title_2 Series_title_3  \
# ...

# %%
df1=pd.read_csv("Business-employment-data-september-2022-quarter-csv.csv",)

# %%
df.describe()
# Out:
#              Period    Data_value     Magnitude  Series_title_4  \
# count  20641.000000  1.614600e+04  20641.000000             0.0
# mean    2016.451399  6.174902e+04      2.367618             NaN
# std        3.279618  1.865759e+05      2.932663             NaN
# min     2011.060000  1.225683e+00      0.000000             NaN
# 25%     2014.030000  1.237843e+03      0.000000             NaN
# 50%     2016.120000  1.064250e+04      0.000000             NaN
# 75%     2019.090000  4.353525e+04      6.000000             NaN
# max     2022.090000  2.207151e+06      6.000000             NaN
#
#        Series_title_5
# count             0.0
# mean              NaN
# std               NaN
# min               NaN
# 25%               NaN
# 50%               NaN
# 75%               NaN
# max               NaN

# %%
df.dtypes
# Out:
# Series_reference     object
# Period              float64
# Data_value          float64
# Suppressed           object
# STATUS               object
# UNITS                object
# Magnitude             int64
# Subject              object
# Group                object
# Series_title_1       object
# Series_title_2       object
# Series_title_3       object
# Series_title_4      float64
# Series_title_5      float64
# dtype: object

# %%
df.head(2)
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS   UNITS  Magnitude  \
# 0      BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number          0
# 1      BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number          0
#
#                           Subject                            Group  \
# 0  Business Data Collection - BDC  Industry by employment variable
# 1  Business Data Collection - BDC  Industry by employment variable
#
#   Series_title_1                     Series_title_2 Series_title_3  \
# 0    Filled jobs  Agriculture, Forestry and Fishing         Actual
# 1    Filled jobs  Agriculture, Forestry and Fishing         Actual
#
#    Series_title_4  Series_title_5
# 0             NaN             NaN
# 1             NaN             NaN

# %%
df.to_csv('result.csv',index=False,columns=['Magnitude','Subject'])

# %%
df1=pd.read_csv('result.csv')

# %% [markdown]
# #

# %%
df1.head()
# Out:
#    Magnitude                         Subject
# 0          0  Business Data Collection - BDC
# 1          0  Business Data Collection - BDC
# 2          0  Business Data Collection - BDC
# 3          0  Business Data Collection - BDC
# 4          0  Business Data Collection - BDC

# %%
df=pd.read_csv("result.csv")

# %%
df.head()
# Out:
#    Magnitude                         Subject
# 0          0  Business Data Collection - BDC
# 1          0  Business Data Collection - BDC
# 2          0  Business Data Collection - BDC
# 3          0  Business Data Collection - BDC
# 4          0  Business Data Collection - BDC

# %%
df.columns
# Out:
# Index(['Magnitude', 'Subject'], dtype='object')

# %%
type(df['Magnitude'])
# Out:
# pandas.core.series.Series

# %%
df['Subject']
# Out:
# 0        Business Data Collection - BDC
# 1        Business Data Collection - BDC
# 2        Business Data Collection - BDC
# 3        Business Data Collection - BDC
# 4        Business Data Collection - BDC
#                       ...
# 20636    Business Data Collection - BDC
# 20637    Business Data Collection - BDC
# 20638    Business Data Collection - BDC
# 20639    Business Data Collection - BDC
# 20640    Business Data Collection - BDC
# Name: Subject, Length: 20641, dtype: object

# %%
df[['Magnitude','Subject']]
# Out:
#        Magnitude                         Subject
# 0              0  Business Data Collection - BDC
# 1              0  Business Data Collection - BDC
# 2              0  Business Data Collection - BDC
# 3              0  Business Data Collection - BDC
# 4              0  Business Data Collection - BDC
# ...          ...                             ...
# 20636          0  Business Data Collection - BDC
# 20637          0  Business Data Collection - BDC
# 20638          0  Business Data Collection - BDC
# 20639          0  Business Data Collection - BDC
# 20640          0  Business Data Collection - BDC
#
# [20641 rows x 2 columns]

# %%
df1[['STATUS','UNITS','Magnitude','Subject']]
# Out:
#       STATUS   UNITS  Magnitude                         Subject
# 0          F  Number          0  Business Data Collection - BDC
# 1          F  Number          0  Business Data Collection - BDC
# 2          F  Number          0  Business Data Collection - BDC
# 3          F  Number          0  Business Data Collection - BDC
# 4          F  Number          0  Business Data Collection - BDC
# ...      ...     ...        ...                             ...
# 20636      C  Number          0  Business Data Collection - BDC
# 20637      C  Number          0  Business Data Collection - BDC
# 20638      C  Number          0  Business Data Collection - BDC
# 20639      C  Number          0  Business Data Collection - BDC
# 20640      C  Number          0  Business Data Collection - BDC
#
# [20641 rows x 4 columns]

# %%
data =pd.read_excel('Book1.xlsx')

# %%
data.head()
# Out:
#    House Age (years)  Distance to Station (meters)  Price per Square Foot  \
# 0               32.0                      84.87882                   75.8
# 1               19.5                     306.59470                   84.4
# 2               13.3                     561.98450                   94.6
# 3               13.3                     561.98450                  109.6
# 4                5.0                     390.56840                   86.2
#
#    Unnamed: 3            Sum  Unnamed: 5
# 0         NaN           Mean         NaN
# 1         NaN         Median         NaN
# 2         NaN           Mode         NaN
# 3         NaN  St. Deviation         NaN
# 4         NaN       Variance         NaN

# %%
data1=pd.read_excel('sampledatafoodsales.xlsx', sheet_name='FoodSales')

# %%
data1.head()
# Out:
#    OrderDate Region         City  Category         Product  Quantity  \
# 0 2020-01-01   East       Boston      Bars          Carrot        33
# 1 2020-01-04   East       Boston  Crackers     Whole Wheat        87
# 2 2020-01-07   West  Los Angeles   Cookies  Chocolate Chip        58
# 3 2020-01-10   East     New York   Cookies  Chocolate Chip        82
# 4 2020-01-13   East       Boston   Cookies       Arrowroot        38
#
#    UnitPrice  TotalPrice
# 0       1.77       58.41
# 1       3.49      303.63
# 2       1.87      108.46
# 3       1.87      153.34
# 4       2.18       82.84

# %%
data1['Product'].mode()
# Out:
# 0    Carrot
# dtype: object

# %%
df4=pd.read_html("https://www.bbc.com/sport/basketball/nba/table")

# %%
type(df4)
# Out:
# list

# %%
len(df4)
# Out:
# 6

# %%
df4[0].head(2)
# Out:
#   Rank                                  Team PlayedP  WonW LostL        Home  \
# 0   11          Boston CelticsBoston Celtics    6868  4747  2121    26-926-9
# 1   22  Philadelphia 76ersPhiladelphia 76ers    6666  4444  2222  25-1025-10
#
#          Away Win PercentagePct     ForPF AgainstPA Unnamed: 10 Unnamed: 11
# 0  21-1221-12        0.6910.691  80148014  76417641         NaN         NaN
# 1  19-1219-12        0.6670.667  75967596  73277327         NaN         NaN

# %%
df4[0].to_csv("Football_league.csv")

# %%
df4[2].to_excel('Football_league_table.xlsx')

# %%
data_tita=pd.read_csv('https://raw.githubusercontent.com/ashishpatel26/Titanic-Machine-Learning-from-Disaster/master/Submission_titanic.csv')

# %%
data_tita.head()
# Out:
#    Unnamed: 0  PassengerId  Sex  Age  Fare  Cabin  Embarked  Title  \
# 0           0          892    0    2     0    2.0         2      0
# 1           1          893    1    3     0    2.0         0      2
# 2           2          894    0    3     0    2.0         2      0
# 3           3          895    0    2     0    2.0         0      0
# 4           4          896    1    1     0    2.0         0      2
#
#    FamilySize  Survived
# 0         0.0         0
# 1         0.4         1
# 2         0.0         0
# 3         0.0         0
# 4         0.8         1

# %%
s = """{
"name":"naman",
"age":25,
"company":"Maruti"
}
"""

# %%
s
# Out:
# '{\n"name":"naman",\n"age":25,\n"company":"Maruti"\n}\n'

# %%
p=json.loads(s)

# %%
p
# Out:
# {'name': 'naman', 'age': 25, 'company': 'Maruti'}

# %%
import requests

# %%
rea=requests.get('https://api.github.com/repos/pandas-dev/pandas/issues')

# %%
p=rea.json()
p[0]['user']
# Out:
# {'login': 'rmhowe425',
#  'id': 45905457,
#  'node_id': 'MDQ6VXNlcjQ1OTA1NDU3',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/45905457?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/rmhowe425',
#  'html_url': 'https://github.com/rmhowe425',
#  'followers_url': 'https://api.github.com/users/rmhowe425/followers',
#  'following_url': 'https://api.github.com/users/rmhowe425/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/rmhowe425/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/rmhowe425/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/rmhowe425/subscriptions',
#  'organizations_url': 'https://api.github.com/users/rmhowe425/orgs',
#  'repos_url': 'https://api.github.com/users/rmhowe425/repos',
#  'events_url': 'https://api.github.com/users/rmhowe425/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/rmhowe425/received_events',
#  'type': 'User',
# ...

# %%
pp=pd.DataFrame(p)

# %%
l=[]
for i in range(len(p)):
    l.append(p[i]['user'])
p_user=pd.DataFrame(l)

# %%
p_user.head()
# Out:
#           login        id               node_id  \
# 0     rmhowe425  45905457  MDQ6VXNlcjQ1OTA1NDU3
# 1        hugovk   1324225  MDQ6VXNlcjEzMjQyMjU=
# 2      dannyi96  15380498  MDQ6VXNlcjE1MzgwNDk4
# 3  DeaMariaLeon  11835246  MDQ6VXNlcjExODM1MjQ2
# 4        uzzell  72205435  MDQ6VXNlcjcyMjA1NDM1
#
#                                           avatar_url gravatar_id  \
# 0  https://avatars.githubusercontent.com/u/459054...
# 1  https://avatars.githubusercontent.com/u/132422...
# 2  https://avatars.githubusercontent.com/u/153804...
# 3  https://avatars.githubusercontent.com/u/118352...
# 4  https://avatars.githubusercontent.com/u/722054...
#
#                                          url                         html_url  \
# 0     https://api.github.com/users/rmhowe425     https://github.com/rmhowe425
# 1        https://api.github.com/users/hugovk        https://github.com/hugovk
# 2      https://api.github.com/users/dannyi96      https://github.com/dannyi96
# ...

# %%
p_user.to_csv("Response.csv")

# %%
df=pd.read_csv('Response.csv')

# %%
df.head()
# Out:
#    Unnamed: 0         login        id               node_id  \
# 0           0     rmhowe425  45905457  MDQ6VXNlcjQ1OTA1NDU3
# 1           1        hugovk   1324225  MDQ6VXNlcjEzMjQyMjU=
# 2           2      dannyi96  15380498  MDQ6VXNlcjE1MzgwNDk4
# 3           3  DeaMariaLeon  11835246  MDQ6VXNlcjExODM1MjQ2
# 4           4        uzzell  72205435  MDQ6VXNlcjcyMjA1NDM1
#
#                                           avatar_url  gravatar_id  \
# 0  https://avatars.githubusercontent.com/u/459054...          NaN
# 1  https://avatars.githubusercontent.com/u/132422...          NaN
# 2  https://avatars.githubusercontent.com/u/153804...          NaN
# 3  https://avatars.githubusercontent.com/u/118352...          NaN
# 4  https://avatars.githubusercontent.com/u/722054...          NaN
#
#                                          url                         html_url  \
# 0     https://api.github.com/users/rmhowe425     https://github.com/rmhowe425
# ...

# %%
df.to_pickle("my_pickle")

# %%
h5_data=pd.HDFStore('test.h5')

# %%
h5_data['col1']=df

# %%
h5_data['col1'].head()
# Out:
#    Unnamed: 0         login        id               node_id  \
# 0           0     rmhowe425  45905457  MDQ6VXNlcjQ1OTA1NDU3
# 1           1        hugovk   1324225  MDQ6VXNlcjEzMjQyMjU=
# 2           2      dannyi96  15380498  MDQ6VXNlcjE1MzgwNDk4
# 3           3  DeaMariaLeon  11835246  MDQ6VXNlcjExODM1MjQ2
# 4           4        uzzell  72205435  MDQ6VXNlcjcyMjA1NDM1
#
#                                           avatar_url  gravatar_id  \
# 0  https://avatars.githubusercontent.com/u/459054...          NaN
# 1  https://avatars.githubusercontent.com/u/132422...          NaN
# 2  https://avatars.githubusercontent.com/u/153804...          NaN
# 3  https://avatars.githubusercontent.com/u/118352...          NaN
# 4  https://avatars.githubusercontent.com/u/722054...          NaN
#
#                                          url                         html_url  \
# 0     https://api.github.com/users/rmhowe425     https://github.com/rmhowe425
# ...

# %%
h5_data.put('obj2',df, format='table')

# %%
h5_data['obj2'].head()
# Out:
#    Unnamed: 0         login        id               node_id  \
# 0           0     rmhowe425  45905457  MDQ6VXNlcjQ1OTA1NDU3
# 1           1        hugovk   1324225  MDQ6VXNlcjEzMjQyMjU=
# 2           2      dannyi96  15380498  MDQ6VXNlcjE1MzgwNDk4
# 3           3  DeaMariaLeon  11835246  MDQ6VXNlcjExODM1MjQ2
# 4           4        uzzell  72205435  MDQ6VXNlcjcyMjA1NDM1
#
#                                           avatar_url  gravatar_id  \
# 0  https://avatars.githubusercontent.com/u/459054...          NaN
# 1  https://avatars.githubusercontent.com/u/132422...          NaN
# 2  https://avatars.githubusercontent.com/u/153804...          NaN
# 3  https://avatars.githubusercontent.com/u/118352...          NaN
# 4  https://avatars.githubusercontent.com/u/722054...          NaN
#
#                                          url                         html_url  \
# 0     https://api.github.com/users/rmhowe425     https://github.com/rmhowe425
# ...

# %%
h5_data.select('obj2', where=['index >=10 and index <= 15'])
# Out:
#     Unnamed: 0             login        id               node_id  \
# 10          10         natmokval  91160475  MDQ6VXNlcjkxMTYwNDc1
# 11          11          dannyi96  15380498  MDQ6VXNlcjE1MzgwNDk4
# 12          12         jameslamb   7608904  MDQ6VXNlcjc2MDg5MDQ=
# 13          13  jayendra-patil33  43951088  MDQ6VXNlcjQzOTUxMDg4
# 14          14      jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 15          15      jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
#
#                                            avatar_url  gravatar_id  \
# 10  https://avatars.githubusercontent.com/u/911604...          NaN
# 11  https://avatars.githubusercontent.com/u/153804...          NaN
# 12  https://avatars.githubusercontent.com/u/760890...          NaN
# 13  https://avatars.githubusercontent.com/u/439510...          NaN
# 14  https://avatars.githubusercontent.com/u/807896...          NaN
# 15  https://avatars.githubusercontent.com/u/807896...          NaN
#
# ...

# %%
df.head()
# Out:
#    Unnamed: 0         login        id               node_id  \
# 0           0     rmhowe425  45905457  MDQ6VXNlcjQ1OTA1NDU3
# 1           1        hugovk   1324225  MDQ6VXNlcjEzMjQyMjU=
# 2           2      dannyi96  15380498  MDQ6VXNlcjE1MzgwNDk4
# 3           3  DeaMariaLeon  11835246  MDQ6VXNlcjExODM1MjQ2
# 4           4        uzzell  72205435  MDQ6VXNlcjcyMjA1NDM1
#
#                                           avatar_url  gravatar_id  \
# 0  https://avatars.githubusercontent.com/u/459054...          NaN
# 1  https://avatars.githubusercontent.com/u/132422...          NaN
# 2  https://avatars.githubusercontent.com/u/153804...          NaN
# 3  https://avatars.githubusercontent.com/u/118352...          NaN
# 4  https://avatars.githubusercontent.com/u/722054...          NaN
#
#                                          url                         html_url  \
# 0     https://api.github.com/users/rmhowe425     https://github.com/rmhowe425
# ...

# %%
df['Sex']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3080, in Index.get_loc(self, key, method, tolerance)
#    3079 try:
# -> 3080     return self._engine.get_loc(casted_key)
#    3081 except KeyError as err:
#
# File pandas\_libs\index.pyx:70, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\index.pyx:101, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:4554, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:4562, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Sex'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[222], line 1
# ----> 1 df['Sex']
#
# ...
