# %%
from tkinter import *
from PIL import ImageTk, Image # libraries to deal with the images of jpg and png format

# %%
# To add images to the app 
root = Tk()


root.title("Second_app")

my_img1 = ImageTk.PhotoImage(Image.open("images/768px-Sign-check-icon.png"))

my_img2 = ImageTk.PhotoImage(Image.open("images/tkinter_img_button.jpg"))

my_img3 = ImageTk.PhotoImage(Image.open("images/tkinter_img1.jpg"))

my_img4 = ImageTk.PhotoImage(Image.open("images/tkinter_img_button.jpg"))

my_img5 = ImageTk.PhotoImage(Image.open("images/tkinter_img_3.jpg"))

img_list=[my_img1,my_img2,my_img3,my_img4,my_img5]





my_label = Label(image=my_img1)
my_label.grid(row=0, column=0 , columnspan=3)

def forward(image_no):
    global my_label
    global button_next
    global button_back
    
    
    my_label.grid_forget()
    
    my_label = Label(image=img_list[image_no - 1])
    button_forward=Button(root,text=">>",command=lambda : forward(image_no+1))
    
    button_back= Button(root , text = "<<" , command = lambda: back(image_no-1))
    
    if image_no == 5:
        button_forward = Button(root, text=">>",state = DISABLED)
    
    my_label.grid(row=0, column=0 , columnspan=3)
    button_back.grid(row=1,column=0)
    button_forward.grid(row=1,column=2)

def back(image_no):
    global my_label
    global button_forward
    global button_back
    
    
    my_label.grid_forget()
    
    my_label = Label(image=img_list[image_no - 1])
    button_forward=Button(root,text=">>",command=lambda : forward(image_no+1))
    
    button_back= Button(root , text = "<<" , command = lambda: back(image_no-1))
    
    if image_no == 1:
        button_back = Button(root, text="<<",state = DISABLED)
    
    my_label.grid(row=0, column=0 , columnspan=3)
    button_back.grid(row=1,column=0)
    button_forward.grid(row=1,column=2)

    
    
    
    
    
    
    
    
    return




button_back= Button(root , text = "<<" , command = lambda: back(),state = DISABLED)
button_exit = Button(root , text = "Exit Program" , command = root.quit)
button_forward = Button(root, text=">>", command=lambda: forward(2))

    
    
button_back.grid(row=1,column=0)
button_exit.grid(row=1,column=1)
button_forward.grid(row=1,column=2)



root.mainloop()

# %%
###

# %%
root = Tk()
root.title("Third_app")


frame=LabelFrame(root,text="This is my frame",padx=50, pady=50) # padding inside container

frame.pack(padx=100,pady=100) # padding outside

b= Button(frame, text="click me!")
b.pack()


root.mainloop()

# %%
root = Tk()
root.title("Third_app")


frame=LabelFrame(root,text="This is my frame",padx=50, pady=50) # padding inside container

frame.pack(padx=100,pady=100) # padding outside

b= Button(frame, text="click me!")

b2= Button(frame, text=" dont click me!")
b.grid(row=0,column=0)
b2.grid(row=1,column=1)


root.mainloop()

# %%
root = Tk()
root.title("Third_app")


frame=LabelFrame(root,padx=50, pady=50) # padding inside container

frame.pack(padx=100,pady=100) # padding outside

b= Button(frame, text="click me!")

b2= Button(frame, text=" dont click me!")
b.grid(row=0,column=0)
b2.grid(row=1,column=1)


root.mainloop()

# %%
## Radio button

root = Tk()
root.title("Radio Button")

r = IntVar()
r.set("2")

def clicked(value):
    
    mylabel = Label(root,text = value)
    mylabel.pack()
Radiobutton(root, text = "Option1" , variable = r, value=1).pack()
Radiobutton(root, text="Option2", variable = r, value=2).pack()

"""mylabel = Label(root,text = r.get())
mylabel.pack()"""

mybutton = Button(root, text = "click me", command= lambda : clicked(r.get()))
mybutton.pack()


root.mainloop()

# %%
## Radio button

root = Tk()
root.title("Radio Button")

#r = IntVar()
#r.set("2")


MODES = [
    
    ("pepporoni","pepporoni"),
    ("cheese","cheese"),
    ("golden corn","golden corn"),
    ("Margherita","Margherita")
]

pizza = StringVar()
pizza.set("pepporoni")

for text,mode in MODES:
    Radiobutton(root, text=text, variable = pizza , value = mode).pack(anchor=W)



def clicked(value):
    
    mylabel = Label(root,text = value)
    mylabel.pack()


#Radiobutton(root, text = "Option1" , variable = r, value=1, command= lambda : clicked(r.get())).pack()
#Radiobutton(root, text="Option2", variable = r, value=2,command= lambda : clicked(r.get())).pack()




#mylabel = Label(root,text = pizza.get())
#mylabel.pack()

mybutton = Button(root, text = "click me", command= lambda : clicked(pizza.get()))
mybutton.pack()


root.mainloop()

# %%
# Message boxes

# %%
# Show info
from tkinter import messagebox
root = Tk()
root.title("Message box")


def popup():
    
    messagebox.showinfo("This is my Popup", "Hello World")  # 1st argument is Title and 2nd argument is Message
    
    
    
Button(root,text="Popup", command = popup).pack()



root.mainloop()

# %%
# Show warning
from tkinter import messagebox
root = Tk()
root.title("Message box")


def popup():
    
    messagebox.showwarning("This is my Popup", "Hello World")  # 1st argument is Title and 2nd argument is Message
    
    
    
Button(root,text="Popup", command = popup).pack()



root.mainloop()

# %%
# showerror
from tkinter import messagebox
root = Tk()
root.title("Message box")


def popup():
    
    messagebox.showerror("This is my Popup", "Hello World")  # 1st argument is Title and 2nd argument is Message
    
    
    
Button(root,text="Popup", command = popup).pack()

root.mainloop()

# %%
# askquestion
from tkinter import messagebox
root = Tk()
root.title("Message box")


def popup():
    
    messagebox.askquestion("This is my Popup", "Hello World")  # 1st argument is Title and 2nd argument is Message
    
    
    
Button(root,text="Popup", command = popup).pack()

root.mainloop()

# %%
# askokcancel
from tkinter import messagebox
root = Tk()
root.title("Message box")


def popup():
    
    messagebox.askokcancel("This is my Popup", "Hello World")  # 1st argument is Title and 2nd argument is Message
    
    
    
Button(root,text="Popup", command = popup).pack()

root.mainloop()

# %%
# askokyesno
from tkinter import messagebox
root = Tk()
root.title("Message box")


def popup():
    
    messagebox.askyesno("This is my Popup", "Hello World")  # 1st argument is Title and 2nd argument is Message
    
    
    
Button(root,text="Popup", command = popup).pack()

root.mainloop()

# %%
# Taking the response into a variable
from tkinter import messagebox
root = Tk()
root.title("Message box")


def popup():
    
    response=messagebox.askokcancel("This is my Popup", "Hello World")  # 1st argument is Title and 2nd argument is Message
   
    if response == 1:
         Label(root, text = "You clicked Ok").pack()
    else:
         Label(root, text = "You clicked Cancel").pack()
Button(root,text="Popup", command = popup).pack()

root.mainloop()

# %%
# Taking the response into a variable
from tkinter import messagebox
root = Tk()
root.title("Message box")


def popup():
    
    response=messagebox.askyesno("This is my Popup", "Hello World")  # 1st argument is Title and 2nd argument is Message
    Label(root, text =response).pack()
Button(root,text="Popup", command = popup).pack()

root.mainloop()

# %%
# Taking the response into a variable
from tkinter import messagebox
root = Tk()
root.title("Message box")


def popup():
    
    response=messagebox.askokcancel("This is my Popup", "Hello World")  # 1st argument is Title and 2nd argument is Message
    Label(root, text =response).pack()
Button(root,text="Popup", command = popup).pack()

root.mainloop()

# %%
# window

# %%
root =Tk()
root.title("New_Window")

top = Toplevel() # new window
top.title("Second_window")
lbl = Label(top, text="Hello world").pack()
my_image = ImageTk.PhotoImage(Image.open("images/0e1e544ad66e7627709c72a9e78e2ad9.jpg"))
my_label = Label(top,image=my_image).pack()


root.mainloop()

# %%
root =Tk()
root.title("New_Window")
def open():
    top = Toplevel() # new window
    top.title("Second_window")
    lbl = Label(top, text="Hello world").pack()
    my_image = ImageTk.PhotoImage(Image.open("images/0e1e544ad66e7627709c72a9e78e2ad9.jpg"))
    my_label = Label(top,image=my_image).pack()


btn = Button(root, text="Open the second window",command=open).pack()

# image doesnt show up



root.mainloop()

# %%
root =Tk()
root.title("New_Window")
def open():
    global my_image
    top = Toplevel() # new window
    top.title("Second_window")
    my_image = ImageTk.PhotoImage(Image.open("images/768px-Sign-check-icon.png"))
    my_label = Label(top,image=my_image).pack()
    bt2=Button(top,text="Close the window",command=top.destroy).pack()

btn = Button(root, text="Open the second window",command=open).pack()

root.mainloop()

# %%
from tkinter import filedialog
# Files dialog box

# %%
root =Tk()
root.title("New_Window")

root.filename = filedialog.askopenfilename(initialdir="/images",title="Select a file", filetypes = (("png files","*.png"),("all files","*."))
root.mainloop()

# %%
#jpeg opening the same file chosen by the user

# %%
root =Tk()
root.title("New_Window")

root.filename = filedialog.askopenfilename(initialdir="/images",title="Select a file", filetypes = (("jpg files","*.jpg"),("all files","*.")))
my_l = Label(root, text = root.filename).pack()
my_i=ImageTk.PhotoImage(Image.open(root.filename))
my_p=Label(image=my_i).pack()
root.mainloop()

# %%
root =Tk()  # returns the location of the particular file we have chosen
root.title("New_Window")

"""root.filename = filedialog.askopenfilename(initialdir="/images",title="Select a file", filetypes = (("jpg files","*.jpg"),("all files","*.")))
my_l = Label(root, text = root.filename).pack()
my_i=ImageTk.PhotoImage(Image.open(root.filename))
my_p=Label(image=my_i).pack()"""
def open1():
    global my_i
    root.filename = filedialog.askopenfilename(initialdir="/images",title="Select a file", filetypes = (("jpg files","*.jpg"),("all files","*.")))
    my_l = Label(root, text = root.filename).pack()
    my_i=ImageTk.PhotoImage(Image.open(root.filename))
    my_p=Label(image=my_i).pack()
my_bt = Button(root, text = "open file", command = open1).pack()
root.mainloop()

# %%
# Slider

# %%
root =Tk()  # returns the location of the particular file we have chosen
root.title("Slider")

vertical = Scale(root, from_ = 0, to=200)
vertical.pack()

horizontal = Scale(root,from_=0,to=200, orient=HORIZONTAL)
horizontal.pack()
root.mainloop()

# %%
# slider with taking its input (root geometry)

# %%
root =Tk()  # returns the location of the particular file we have chosen
root.title("Slider")
root.geometry("400x400")
vertical = Scale(root, from_ = 0, to=200)
vertical.pack()

horizontal = Scale(root,from_=0,to=200, orient=HORIZONTAL)
horizontal.pack()

my_label = Label(root, text=horizontal.get()).pack()

def slide():
    my_label = Label(root, text=horizontal.get()).pack()
    

my_btn = Button(root,text ="Click me", command=slide).pack()
root.mainloop()

# %%
#

# %%
root =Tk()  # returns the location of the particular file we have chosen
root.title("Slider")
root.geometry("400x400")
vertical = Scale(root, from_ = 0, to=200)
vertical.pack()

horizontal = Scale(root,from_=0,to=200, orient=HORIZONTAL)
horizontal.pack()

my_label = Label(root, text=horizontal.get()).pack()

def slide():
    my_label = Label(root, text=horizontal.get()).pack()
    root.geometry(str(horizontal.get()) + "x400")

my_btn = Button(root,text ="Click me", command=slide).pack()
root.mainloop()

# %%
# automatically updating

# %%
root =Tk()  # returns the location of the particular file we have chosen
root.title("Slider")
root.geometry("400x400")
vertical = Scale(root, from_ = 0, to=200)
vertical.pack()

def slide():
    my_label = Label(root, text=horizontal.get()).pack()
    root.geometry(str(horizontal.get()) + "x"+ str(vertical.get()))



horizontal = Scale(root,from_=0,to=200, orient=HORIZONTAL)
horizontal.pack()

my_label = Label(root, text=horizontal.get()).pack()


my_btn = Button(root,text ="Click me", command=slide).pack()
root.mainloop()

# %%
# checkboxes

# %%
root =Tk()  # returns the location of the particular file we have chosen
root.title("Checkboxes")
root.geometry("400x400")


def show():
    my_label = Label(root,text=var.get()).pack()


var = IntVar()


c=Checkbutton(root,text="this box 1",variable=var)
c.pack()

#my_label = Label(root,text=var.get()).pack()

mybtn=Button(root,text="show selection",command = show).pack()


root.mainloop()

# %%
#

# %%
root =Tk()  # returns the location of the particular file we have chosen
root.title("Checkboxes")
root.geometry("400x400")


def show():
    my_label = Label(root,text=var.get()).pack()


var = StringVar()


c=Checkbutton(root,text="this box 1",variable=var,onvalue="On",offvalue="off")
c.pack()

my_label = Label(root,text=var.get()).pack()

mybtn=Button(root,text="show selection",command = show).pack()


root.mainloop()

# %%
# Drop Down menu

# %%
root =Tk()  # returns the location of the particular file we have chosen
root.title("Checkboxes")
root.geometry("400x400")

#Option menu
clicked = StringVar()


drop =OptionMenu(root,clicked, "Monday","Tuesday","Wednesday","Thursday","Friday")
drop.pack()



root.mainloop()

# %%
# default value added

# %%
root =Tk()  # returns the location of the particular file we have chosen
root.title("Checkboxes")
root.geometry("400x400")

def show():
    mylabel=Label(root, text=clicked.get()).pack()

#Option menu
clicked = StringVar()

clicked.set("Monday")

drop =OptionMenu(root,clicked, "Monday","Tuesday","Wednesday","Thursday","Friday","Saturday")
drop.pack()
mybtn=Button(root, text="show_selection",command=show).pack()


root.mainloop()

# %%
# More neater code

# %%
root =Tk()  # returns the location of the particular file we have chosen
root.title("Checkboxes")
root.geometry("400x400")

def show():
    mylabel=Label(root, text=clicked.get()).pack()

    
Options=[
    "Monday","Tuesday","Wednesday","Thursday","Friday","Saturday"
]
#Option menu
clicked = StringVar()

clicked.set(Options[0])

drop =OptionMenu(root,clicked, *Options)
drop.pack()
mybtn=Button(root, text="show_selection",command=show).pack()


root.mainloop()

# %%
# Connecting/Creating with database

# %%
import sqlite3

# %%
root =Tk()  # returns the location of the particular file we have chosen
root.title("Checkboxes")
root.geometry("400x400")

# Database


#Create a database or connect to one 
conn = sqlite3.connect("address_book.db")
#Create a cursor
c=conn.cursor()

#Create table
c.execute("""

CREATE TABLE addresses (
    first_name text,
    last_name text,
    address text,
    city text,
    state text,
    zipcode integer
)
""")







#Commit changes
conn.commit()
#conn.close
conn.close()
root.mainloop()

# %%
#

# %%
root =Tk()  # returns the location of the particular file we have chosen
root.title("Checkboxes")
root.geometry("400x400")

# Database


#Create a database or connect to one 
conn = sqlite3.connect("address_book.db")
#Create a cursor
c=conn.cursor()

#Create table


def submit():
    #Create a database or connect to one 
    conn = sqlite3.connect("address_book.db")
    #Create a cursor
    c=conn.cursor() 
    
    # Insert into table
    
    c.execute("INSERT INTO addresses VALUES (:f_name, :l_name, :address, :city, :state, :zipcode)",
             {
                 'f_name': f_name.get(),
                 'l_name':l_name.get(),
                 'address':address.get(),
                 'city':city.get(),
                 'state':state.get(),
                 'zipcode':zipcode.get()
                 
             })

    conn.commit()
    conn.close()
    

    f_name.delete(0,END)
    l_name.delete(0,END)
    address.delete(0,END)
    city.delete(0,END)
    state.delete(0,END)
    zipcode.delete(0,END)
    
    return

def query():
    
    #Create a database or connect to one 
    conn = sqlite3.connect("address_book.db")
    #Create a cursor
    c=conn.cursor() 
    
    # query the database
    
    c.execute("SELECT *,oid FROM addresses")
    records=c.fetchall()
    #print(records)
    print_record=""
    for record in records:
        print_record += str(record) + "\n"
        
    query_label=Label(root, text=print_record)
    query_label.grid(row=11,column=0,columnspan=2)
    
    
    
    
    conn.commit()
    conn.close()

def delete1():
    #Create a database or connect to one 
    conn = sqlite3.connect("address_book.db")
    #Create a cursor
    c=conn.cursor() 

    c.execute("DELETE from addresses WHERE oid ={}".format(delete_box.get()))
    
    
    delete_box.delete(0,END)
    conn.commit()
    conn.close()








# Create text boxes
f_name = Entry(root,width=30)
f_name.grid(row=0,column=1,padx=20,pady=(10,0))


l_name = Entry(root,width=30)
l_name.grid(row=1,column=1,padx=20)

address = Entry(root,width=30)
address.grid(row=2,column=1,padx=20)

city = Entry(root,width=30)
city.grid(row=3,column=1,padx=20)

state = Entry(root,width=30)
state.grid(row=4,column=1,padx=20)

zipcode = Entry(root,width=30)
zipcode.grid(row=5,column=1,padx=20)

delete_box=Entry(root,width=30)
delete_box.grid(row=9,column=1,padx=20,pady=5)


# Text box labels
f_name_label = Label(root,text="first name")
f_name_label.grid(row=0,column=0)
l_name_label = Label(root,text="last name")
l_name_label.grid(row=1,column=0)
a_name_label = Label(root,text="address")
a_name_label.grid(row=2,column=0)
c_name_label = Label(root,text="city")
c_name_label.grid(row=3,column=0)
s_name_label = Label(root,text="state")
s_name_label.grid(row=4,column=0)
z_name_label = Label(root,text="zipcode")
z_name_label.grid(row=5,column=0)
delete_label=Label(root,text="Delete ID Number")
delete_label.grid(row=9,column=0,pady=5)
# Create submit button

submit_btn = Button(root, text="Add record to data base",command=submit)
submit_btn.grid(row=6,column=0,columnspan=2,pady=10,padx=10,ipadx=107)
# create query button

query_btn = Button(root, text="show records",command=query)
query_btn.grid(row=7,column=0,columnspan=2,pady=10,padx=10,ipadx=137)

# Delete button
delete_btn = Button(root,text="Delete Records",command=delete1)
delete_btn.grid(row=10,column=0,columnspan=2,pady=10,padx=10,ipadx=134)


#Commit changes
conn.commit()
#conn.close
conn.close()
root.mainloop()
